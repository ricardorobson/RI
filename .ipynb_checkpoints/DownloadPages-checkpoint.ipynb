# %%
import requests as rq
import pandas as pd
import io
import os
import shutil
#pip install tldextract
import tldextract

from requests.packages.urllib3.exceptions import InsecureRequestWarning

rq.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
dataFrame = pd.read_csv('Links.csv')
dataFrame
# Out:
#                                       Site  \
# 0            https://www.doctoralia.com.br
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11   https://www.psicologosdobrasil.com.br
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21      https://www.psicologiaviva.com.br/
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# ..                                     ...
# 72                 https://www.vittude.com
# 73                                     NaN
# 74                                     NaN
# 75                                     NaN
# 76                                     NaN
# 77                                     NaN
# 78                                     NaN
# 79                                     NaN
# 80                                     NaN
# 81                                     NaN
# 82        http://www.classificados.com.br/
# 83                                     NaN
# 84                                     NaN
# 85                                     NaN
# 86                                     NaN
# 87                                     NaN
# 88                                     NaN
# 89                                     NaN
# 90                                     NaN
# 91                                     NaN
# 92             https://www.telelistas.net/
# 93                                     NaN
# 94                                     NaN
# 95                                     NaN
# 96                                     NaN
# 97                                     NaN
# 98                                     NaN
# 99                                     NaN
# 100                                    NaN
# 101                                    NaN
#
#                                      Páginas positivas  \
# 0    https://www.doctoralia.com.br/medico/alexandre...
# 1    https://www.doctoralia.com.br/medico/canuto+lu...
# 2    https://www.doctoralia.com.br/medico/schieveni...
# 3    https://www.doctoralia.com.br/medico/azevedo+s...
# 4    https://www.doctoralia.com.br/medico/m+brosig+...
# 5    https://www.doctoralia.com.br/medico/dias+nasc...
# 6    https://www.doctoralia.com.br/medico/simionato...
# 7    https://www.doctoralia.com.br/medico/noia+matt...
# 8    https://www.doctoralia.com.br/medico/arouca+ca...
# 9    https://www.doctoralia.com.br/medico/fasoli+re...
# 10   https://www.doctoralia.com.br/medico/costa+igo...
# 11   https://www.psicologosdobrasil.com.br/detalhes...
# 12   https://www.psicologosdobrasil.com.br/detalhes...
# 13   https://www.psicologosdobrasil.com.br/detalhes...
# 14   https://www.psicologosdobrasil.com.br/detalhes...
# 15   https://www.psicologosdobrasil.com.br/detalhes...
# 16   https://www.psicologosdobrasil.com.br/detalhes...
# 17   https://www.psicologosdobrasil.com.br/detalhes...
# 18   https://www.psicologosdobrasil.com.br/detalhes...
# 19   https://www.psicologosdobrasil.com.br/detalhes...
# 20   https://www.psicologosdobrasil.com.br/detalhes...
# 21           https://www.psicologiaviva.com.br/rejapsi
# 22    https://www.psicologiaviva.com.br/terezinha.melo
# 23   https://www.psicologiaviva.com.br/leticiasegre...
# 24           https://www.psicologiaviva.com.br/conrado
# 25   https://www.psicologiaviva.com.br/angelicacarp...
# 26    https://www.psicologiaviva.com.br/isabelazambuja
# 27     https://www.psicologiaviva.com.br/fatimabaracho
# 28     https://www.psicologiaviva.com.br/rosanateshima
# 29    https://www.psicologiaviva.com.br/gabrielleprado
# ..                                                 ...
# 72   https://www.vittude.com/psicologo/jose-soares-...
# 73   https://www.vittude.com/psicologo/ysis-santos-...
# 74   https://www.vittude.com/psicologo/cristina-fer...
# 75   https://www.vittude.com/psicologo/andrea-crist...
# 76   https://www.vittude.com/psicologo/stephanie-kr...
# 77   https://www.vittude.com/psicologo/aline-maria-...
# 78   https://www.vittude.com/psicologo/gil-ferreira...
# 79    https://www.vittude.com/psicologo/jessye-cantini
# 80   https://www.vittude.com/psicologo/nathalia-san...
# 81   https://www.vittude.com/psicologo/milena-puga-...
# 82   http://www.classificados.com.br/sao_paulo_ana_...
# 83   http://www.classificados.com.br/minas_gerais_p...
# 84   http://www.classificados.com.br/rio_de_janeiro...
# 85   http://www.classificados.com.br/sao_paulo_psic...
# 86   http://www.classificados.com.br/sao_paulo_psic...
# 87   http://www.classificados.com.br/rio_de_janeiro...
# 88   http://www.classificados.com.br/rio_grande_do_...
# 89   http://www.classificados.com.br/sao_paulo_luan...
# 90   http://www.classificados.com.br/sao_paulo_luan...
# 91   http://www.classificados.com.br/santa_catarina...
# 92   https://www.telelistas.net/locais/rj/rio+de+ja...
# 93   https://www.telelistas.net/locais/rj/rio+de+ja...
# 94   https://www.telelistas.net/locais/pe/recife/ps...
# 95   https://www.telelistas.net/locais/mg/belo+hori...
# 96   https://www.telelistas.net/locais/mg/uberlandi...
# 97   https://www.telelistas.net/locais/go/goiania/p...
# 98   https://www.telelistas.net/locais/go/goiania/p...
# 99   https://www.telelistas.net/locais/rj/rio+de+ja...
# 100  https://www.telelistas.net/locais/mg/belo+hori...
# 101  https://www.telelistas.net/locais/mg/belo+hori...
#
#                                      Páginas negativas  \
# 0                        https://www.doctoralia.com.br
# 1         https://www.doctoralia.com.br/users/register
# 2         https://app.doctoralia.com.br/usuarios/login
# 3     https://www.doctoralia.com.br/quem-somos-contato
# 4    https://www.doctoralia.com.br/quem-somos-conta...
# 5                  https://www.docplanner.com/about-us
# 6             https://www.doctoralia.com.br/legal.aspx
# 7    https://www.doctoralia.com.br/pergunte-ao-espe...
# 8                      https://blog.doctoralia.com.br/
# 9                    https://twitter.com/Doctoralia_br
# 10             https://www.facebook.com/doctoralia.br/
# 11               https://www.psicologosdobrasil.com.br
# 12     https://www.psicologosdobrasil.com.br/sobre.php
# 13   https://www.psicologosdobrasil.com.br/anuncie.php
# 14   https://www.psicologosdobrasil.com.br/artigos.php
# 15   https://www.psicologosdobrasil.com.br/noticias...
# 16   https://www.psicologosdobrasil.com.br/pergunte...
# 17   https://www.psicologosdobrasil.com.br/areapsic...
# 18   https://www.psicologosdobrasil.com.br/contato.php
# 19   https://www.psicologosdobrasil.com.br/pergunta...
# 20    https://www.psicologosdobrasil.com.br/cursos.php
# 21      https://www.psicologiaviva.com.br/empresarial/
# 22   https://www.psicologiaviva.com.br/consultorioo...
# 23   https://www.psicologiaviva.com.br/consultorioo...
# 24         https://psicologiaviva.zendesk.com/hc/pt-br
# 25     https://www.psicologiaviva.com.br/eficacia.html
# 26   https://www.psicologiaviva.com.br/consultorioo...
# 27   https://psicologiaviva.zendesk.com/hc/pt-br/ca...
# 28   https://psicologiaviva.zendesk.com/hc/pt-br/se...
# 29   https://psicologiaviva.zendesk.com/hc/pt-br/ar...
# ..                                                 ...
# 72                         https://www.vittude.com/faq
# 73                  https://www.vittude.com/quem-somos
# 74             https://www.vittude.com/termos-paciente
# 75                 https://www.vittude.com/privacidade
# 76           https://www.vittude.com/termos-psicologos
# 77                                                 NaN
# 78                                                 NaN
# 79                                                 NaN
# 80                                                 NaN
# 81                                                 NaN
# 82   http://www.classificados.com.br/index.php?page...
# 83   http://www.classificados.com.br/index.php?page...
# 84   http://www.classificados.com.br/index.php?page...
# 85          http://www.classificados.com.br/pg-03.html
# 86                   http://classificados.com.br/hesk/
# 87   http://www.classificados.com.br/animais_pets-b...
# 88   http://www.classificados.com.br/antiguidades-b...
# 89   http://www.classificados.com.br/jogos-b100589....
# 90                                                 NaN
# 91                                                 NaN
# 92   https://www.telelistas.net/templates/promocoes...
# 93   https://www.telelistas.net/templates/form_logi...
# 94                    http://www.telelistas.net/mobile
# 95   https://www.telelistas.net/templates/telesite....
# 96   https://www.telelistas.net/templates/form_fale...
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
#
#                                          Páginas Maybe Responsável
# 0    https://www.doctoralia.com.br/noindex/medicos/...        dls4
# 1    https://www.doctoralia.com.br/noindex/medicos/...        dls4
# 2    https://www.doctoralia.com.br/noindex/medicos/...        dls4
# 3    https://www.doctoralia.com.br/noindex/medicos/...        dls4
# 4                https://www.doctoralia.com.br/medicos        dls4
# 5                                                  NaN        dls4
# 6                                                  NaN        dls4
# 7                                                  NaN        dls4
# 8                                                  NaN        dls4
# 9                                                  NaN        dls4
# 10                                                 NaN        dls4
# 11   https://www.psicologosdobrasil.com.br/diretori...        dls4
# 12                                                 NaN        dls4
# 13                                                 NaN        dls4
# 14                                                 NaN        dls4
# 15                                                 NaN        dls4
# 16                                                 NaN        dls4
# 17                                                 NaN        dls4
# 18                                                 NaN        dls4
# 19                                                 NaN        dls4
# 20                                                 NaN        dls4
# 21     https://www.psicologiaviva.com.br/catalogo.html        dls4
# 22   https://www.psicologiaviva.com.br/catalogo.htm...        dls4
# 23   https://www.psicologiaviva.com.br/catalogo.htm...        dls4
# 24                  https://www.psicologiaviva.com.br/        dls4
# 25                                                 NaN        dls4
# 26                                                 NaN        dls4
# 27                                                 NaN        dls4
# 28                                                 NaN        dls4
# 29                                                 NaN        dls4
# ..                                                 ...         ...
# 72           https://www.vittude.com/psicologos/recife         tpa
# 73                 https://www.vittude.com/psicologos/         tpa
# 74   https://www.vittude.com/psicologos/sao-paulo/s...         tpa
# 75   https://www.vittude.com/psicologos/sao-paulo/a...         tpa
# 76                            https://www.vittude.com/         tpa
# 77                                                 NaN         tpa
# 78                                                 NaN         tpa
# 79                                                 NaN         tpa
# 80                                                 NaN         tpa
# 81                                                 NaN         tpa
# 82   http://www.classificados.com.br/psicologos-b63...         tpa
# 83                    http://www.classificados.com.br/         tpa
# 84                                                 NaN         tpa
# 85                                                 NaN         tpa
# 86                                                 NaN         tpa
# 87                                                 NaN         tpa
# 88                                                 NaN         tpa
# 89                                                 NaN         tpa
# 90                                                 NaN         tpa
# 91                                                 NaN         tpa
# 92   https://www.telelistas.net/br/psicanalistas?le...         tpa
# 93   https://www.telelistas.net/br/psicanalistas?pa...         tpa
# 94   https://www.telelistas.net/br/psicanalistas?le...         tpa
# 95   https://www.telelistas.net/br/psicanalistas?pa...         tpa
# 96   https://www.telelistas.net/br/psicanalistas?le...         tpa
# 97                                                 NaN         tpa
# 98                                                 NaN         tpa
# 99                                                 NaN         tpa
# 100                                                NaN         tpa
# 101                                                NaN         tpa
#
# [102 rows x 5 columns]

# %% [markdown]
# ### Download positive pages

# %%
dir = 'Pages'
if os.path.exists(dir):
    shutil.rmtree(dir)
os.makedirs(dir)
os.makedirs(dir+'/Positives/')

index = 0
last_domain = ''

for url in dataFrame['Páginas positivas']:
    page = rq.get(url, verify=False)
    domain = tldextract.extract(url).domain
    print(domain)
    
    if(domain != last_domain):
        print(last_domain)
        last_domain = domain
        os.makedirs(dir+'/Positives/'+domain)
        index = 0
    
    f = io.open(dir+'/Positives/'+domain+'/'+str(index)+'.html', 'w', encoding="utf-8")
    f.write(page.text)
    f.close()
    print(index)
    index += 1
# Out:
# doctoralia
#
# 0
# doctoralia
# 1
# doctoralia
# 2
# doctoralia
# 3
# doctoralia
# 4
# doctoralia
# 5
# doctoralia
# 6
# doctoralia
# 7
# doctoralia
# 8
# doctoralia
# 9
# doctoralia
# 10
# psicologosdobrasil
# doctoralia
# 0
# psicologosdobrasil
# 1
# psicologosdobrasil
# 2
# psicologosdobrasil
# 3
# psicologosdobrasil
# 4
# psicologosdobrasil
# 5
# psicologosdobrasil
# 6
# psicologosdobrasil
# 7
# psicologosdobrasil
# 8
# psicologosdobrasil
# 9
# psicologiaviva
# psicologosdobrasil
# 0
# psicologiaviva
# 1
# psicologiaviva
# 2
# psicologiaviva
# 3
# psicologiaviva
# 4
# psicologiaviva
# 5
# psicologiaviva
# 6
# psicologiaviva
# 7
# psicologiaviva
# 8
# psicologiaviva
# 9
# psicologiaviva
# 10
# mundopsicologos
# psicologiaviva
# 0
# mundopsicologos
# 1
# mundopsicologos
# 2
# mundopsicologos
# 3
# mundopsicologos
# 4
# mundopsicologos
# 5
# mundopsicologos
# 6
# mundopsicologos
# 7
# mundopsicologos
# 8
# mundopsicologos
# 9
# guiamais
# mundopsicologos
# 0
# guiamais
# 1
# guiamais
# 2
# guiamais
# 3
# guiamais
# 4
# guiamais
# 5
# guiamais
# 6
# guiamais
# 7
# guiamais
# 8
# guiamais
# 9
# zenklub
# guiamais
# 0
# zenklub
# 1
# zenklub
# 2
# zenklub
# 3
# zenklub
# 4
# zenklub
# 5
# zenklub
# 6
# zenklub
# 7
# zenklub
# 8
# zenklub
# 9
# psicolink
# zenklub
# 0
# psicolink
# 1
# psicolink
# 2
# psicolink
# 3
# psicolink
# 4
# psicolink
# 5
# psicolink
# 6
# psicolink
# 7
# psicolink
# 8
# psicolink
# 9
# vittude
# psicolink
# 0
# vittude
# 1
# vittude
# 2
# vittude
# 3
# vittude
# 4
# vittude
# 5
# vittude
# 6
# vittude
# 7
# vittude
# 8
# vittude
# 9
# classificados
# vittude
# 0
# classificados
# 1
# classificados
# 2
# classificados
# 3
# classificados
# 4
# classificados
# 5
# classificados
# 6
# classificados
# 7
# classificados
# 8
# classificados
# 9
# telelistas
# classificados
# 0
# telelistas
# 1
# telelistas
# 2
# telelistas
# 3
# telelistas
# 4
# telelistas
# 5
# telelistas
# 6
# telelistas
# 7
# telelistas
# 8
# telelistas
# 9

# %% [markdown]
# ### Download negative pages

# %%
os.makedirs(dir+'/Negatives/')
index = 0
last_domain = ''

for url in dataFrame['Páginas negativas'].dropna():
    page = rq.get(url, verify=False)
    domain = tldextract.extract(url).domain
    print(domain)
    
    if(domain != last_domain):
        index = 0
        print(last_domain)
        last_domain = domain
        if  os.path.exists(dir+'/Negatives/'+domain):
            index = len(os.listdir(dir+'/Negatives/'+domain))
        else:
            os.makedirs(dir+'/Negatives/'+domain)
    
    f = io.open(dir+'/Negatives/'+domain+'/'+str(index)+'.html', 'w', encoding="utf-8")
    f.write(page.text)
    f.close()
    print(index)
    index += 1
# Out:
# doctoralia
#
# 0
# doctoralia
# 1
# doctoralia
# 2
# doctoralia
# 3
# doctoralia
# 4
# docplanner
# doctoralia
# 0
# doctoralia
# docplanner
# 5
# doctoralia
# 6
# doctoralia
# 7
# twitter
# doctoralia
# 0
# facebook
# twitter
# 0
# psicologosdobrasil
# facebook
# 0
# psicologosdobrasil
# 1
# psicologosdobrasil
# 2
# psicologosdobrasil
# 3
# psicologosdobrasil
# 4
# psicologosdobrasil
# 5
# psicologosdobrasil
# 6
# psicologosdobrasil
# 7
# psicologosdobrasil
# 8
# psicologosdobrasil
# 9
# psicologiaviva
# psicologosdobrasil
# 0
# psicologiaviva
# 1
# psicologiaviva
# 2
# zendesk
# psicologiaviva
# 0
# psicologiaviva
# zendesk
# 3
# psicologiaviva
# 4
# zendesk
# psicologiaviva
# 1
# zendesk
# 2
# zendesk
# 3
# zendesk
# 4
# zendesk
# 5
# mundopsicologos
# zendesk
# 0
# mundopsicologos
# 1
# mundopsicologos
# 2
# mundopsicologos
# 3
# mundopsicologos
# 4
# vivacupom
# mundopsicologos
# 0
# guiamais
# vivacupom
# 0
# guiamais
# 1
# guiamais
# 2
# guiamais
# 3
# zenklub
# guiamais
# 0
# zenklub
# 1
# typeform
# zenklub
# 0
# zenklub
# typeform
# 2
# zenklub
# 3
# psicolink
# zenklub
# 0
# psicolink
# 1
# psicolink
# 2
# psicolink
# 3
# psicolink
# 4
# psicolink
# 5
# vittude
# psicolink
# 0
# vittude
# 1
# vittude
# 2
# vittude
# 3
# vittude
# 4
# classificados
# vittude
# 0
# classificados
# 1
# classificados
# 2
# classificados
# 3
# classificados
# 4
# classificados
# 5
# classificados
# 6
# classificados
# 7
# telelistas
# classificados
# 0
# telelistas
# 1
# telelistas
# 2
# telelistas
# 3
# telelistas
# 4

# %% [markdown]
# ### Download maybe pages

# %%
os.makedirs(dir+'/Maybe/')
index = 0
last_domain = ''

for url in dataFrame['Páginas Maybe'].dropna():
    page = rq.get(url, verify=False)
    domain = tldextract.extract(url).domain
    print(domain)
    
    if(domain != last_domain):
        print(last_domain)
        last_domain = domain
        os.makedirs(dir+'/Maybe/'+domain)
        index = 0
    
    f = io.open(dir+'/Maybe/'+domain+'/'+str(index)+'.html', 'w', encoding="utf-8")
    f.write(page.text)
    f.close()
    print(index)
    index += 1
# Out:
# doctoralia
#
# 0
# doctoralia
# 1
# doctoralia
# 2
# doctoralia
# 3
# doctoralia
# 4
# psicologosdobrasil
# doctoralia
# 0
# psicologiaviva
# psicologosdobrasil
# 0
# psicologiaviva
# 1
# psicologiaviva
# 2
# psicologiaviva
# 3
# mundopsicologos
# psicologiaviva
# 0
# mundopsicologos
# 1
# guiamais
# mundopsicologos
# 0
# guiamais
# 1
# guiamais
# 2
# guiamais
# 3
# zenklub
# guiamais
# 0
# zenklub
# 1
# zenklub
# 2
# psicolink
# zenklub
# 0
# psicolink
# 1
# psicolink
# 2
# psicolink
# 3
# vittude
# psicolink
# 0
# vittude
# 1
# vittude
# 2
# vittude
# 3
# vittude
# 4
# classificados
# vittude
# 0
# classificados
# 1
# telelistas
# classificados
# 0
# telelistas
# 1
# telelistas
# 2
# telelistas
# 3
# telelistas
# 4
