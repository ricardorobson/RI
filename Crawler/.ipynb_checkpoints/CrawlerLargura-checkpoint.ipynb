# %% [markdown]
# # Crawller - Psicologos
# ## Crawler em largura
# Este notebook dispõe de um crawller para páginas contendo instâncias de psicologos, psiquiatras, clínicas e outros profissionais neste domínio.

# %%
import pandas as pd
import numpy as np
import scipy as scp
from bs4 import BeautifulSoup
import requests as rq
import re
import time
import random

# %% [markdown]
# ## Sementes
#
# Partiremos de "sementes", que são sites dos quais já analisamos manualmente anteriormente e é sabido que levam a instâncias de profissionais do nosso domínio.

# %%
df = pd.read_csv('sementes.csv')
df
# Out:
#                                               semente  \
# 0                           https://www.srlupa.com.br
# 1                              https://serviceira.com
# 2                              https://conectu.com.br
# 3                    https://www.achouservicos.com.br
# 4   https://www.telelistas.net/br/clinicas+de+psic...
# 5   https://www.telelistas.net/br/clinicas+psiquia...
# 6         https://www.telelistas.net/br/psicanalistas
# 7            https://www.telelistas.net/br/psicologos
# 8        https://www.telelistas.net/br/psicopedagogos
# 9                           https://freelancer.com.br
# 10  https://www.doctoralia.com.br/medicos/especial...
# 11              https://www.psicologosdobrasil.com.br
# 12                 https://www.psicologiaviva.com.br/
#
#                       dominio  robotstxt  \
# 0               srlupa.com.br      False
# 1              serviceira.com      False
# 2              conectu.com.br      False
# 3        achouservicos.com.br      False
# 4              telelistas.net       True
# 5              telelistas.net       True
# 6              telelistas.net       True
# 7              telelistas.net       True
# 8              telelistas.net       True
# 9           freelancer.com.br       True
# 10          doctoralia.com.br       True
# 11  psicologosdobrasil.com.br      False
# 12      psicologiaviva.com.br       True
#
#                                            localpath               htmlname
# 0                             pages/sementes/srlupa/                 srlupa
# 1                         pages/sementes/serviceira/             serviceira
# 2                            pages/sementes/conectu/                conectu
# 3                      pages/sementes/achouservicos/          achouservicos
# 4    pages/sementes/telelistas/clinicasdepsicologia/   clinicasdepsicologia
# 5   pages/sementes/telelistas/clinicaspsiquiatricas/  clinicaspsiquiatricas
# 6           pages/sementes/telelistas/psicanalistas/          psicanalistas
# 7              pages/sementes/telelistas/psicologos/             psicologos
# 8          pages/sementes/telelistas/psicopedagogos/         psicopedagogos
# 9                         pages/sementes/freelancer/             freelancer
# 10                        pages/sementes/doctoralia/             doctoralia
# 11                pages/sementes/psicologosdobrasil/     psicologosdobrasil
# 12                    pages/sementes/psicologiaviva/         psicologiaviva

# %% [markdown]
# ## Robots.txt
#
# Nossa primeira preocupação é respeitar o robots.txt disponível no site que vamos crawllear.
# Há bibliotecas para tal funcionalidade. Para os domínios das sementes já havia, previamente, baixado teus robots.txt (quando existia).
#
# O metodo getDisallows(path) abaixo recebe o path onde está a semente e o robots.txt e, iterando sobre ele, retorna a lista de
# restrições do robots.txt.

# %%
def getDisallows(path):
    ret_list = []
    file = open(path+"robots.txt", "r")
    lines = file.readlines()
    read = False
    for line in lines:
        if(line.endswith("\n")):
            line = line[:-1]
        if(line.lower().startswith("user-agent:") and line.endswith("*")):
            read = True
        elif(line.lower().startswith("user-agent:") and not(line.endswith("*"))):
            read = False
        elif(line.lower().startswith("disallow:") and read):
            aux = line[10:]
            
            if(aux.endswith("*")):
                aux = aux[:-1]
            if(aux.endswith("?")):
                aux = aux[:-1]
            if(aux.endswith("?")):
                aux = aux[:-1]
            if(aux.endswith("*")):
                aux = aux[:-1]
                
            ret_list.append(aux)
    return ret_list

# %% [markdown]
# ## Crawleando em largura
#
# Neste primeiro momento, rodo o Crawller partindo de cada semente, iterativamente. É uma busca em largura, onde - por
# motivos de eficiencia - só entro numa página uma vez, só acesso links .html e checo se estou dentro dos domínios das sementes (para evitar sair do domínio para um site como, por exemplo, google.com).
# Também respeitaremos os sites dando um time entre uma requisição e a próxima.

# %%
time_to_sleep = 1
limiar = 1000
dict_link_accessed = {}

def putLinkToAccessList(domain, link):
    link = link.get('href')
    if link is None:
        return link_to_access_list
    
    if domain in link:
        if (link not in link_to_access_list):
            link_to_access_list.append(link)
            return link_to_access_list
    elif link.startswith("/"):
        if (domain+link not in link_to_access_list):
            link_to_access_list.append(domain+link)
            return link_to_access_list
     
    
for i in range(len(df)):
    domain_block_list = []
    link_accessed_list = []
    link_to_access_list = []
    #iterando na semente
    domain = df['dominio'][i]
    print("Crawleando a semente:\t"+domain)
    link_accessed_list.append(df['semente'][i])    
    path = df['localpath'][i]
    
    if(df['robotstxt'][i]):
        domain_block_list = getDisallows(path)
        print("Esta semente contém um Robots.txt com restrições em:\t"+str(domain_block_list))
        
        
    url = path+df['htmlname'][i]+".html"
    parsed_page = BeautifulSoup(open(url,encoding="latin1"),"html.parser")
    print("Iniciando Crawler nesta semente em:\t"+str(url))
    total_links = parsed_page.find_all('a')
    print("Total de links na página:\t"+str(len(total_links)))

    lenght_front_count_aux = len(link_to_access_list)
    
    
    for link in total_links:
        putLinkToAccessList(domain,link)                           
                            
    lenght_front_count_aux = len(link_to_access_list) - lenght_front_count_aux
    print("Total de links adicionados a fronteira:\t"+str(lenght_front_count_aux))
    
    time_to_sleep_aux = random.randint(1,time_to_sleep)
    print("Aguardando "+str(time_to_sleep_aux)+" segundos para a próxima requisição")
    #time.sleep(time_to_sleep_aux)
    
    for link in link_to_access_list:
        if(not link.startswith("http://") and not link.startswith("https://")):
            link = "http://"+link
        print("Tentando acessar "+link+"   ...")
        block = False
        for blockitem in domain_block_list:
            if(blockitem in link):
                block = True
                print("URL bloqueada pelo robots.txt")
                break
        if(not block and link not in link_accessed_list):
            try:
                ret=rq.get(link)
                if 'text/html' in ret.headers['Content-Type']:
                    print("Página acessada com sucesso")
                    link_accessed_list.append(link)
                    

                    if len(link_accessed_list)==limiar:
                        print("LIMIAR ATINGIDO! Foram acessadas "+str(limiar)+" links nesta semente\n\n")
                        dict_link_accessed[domain] = link_accessed_list
                        break

                    parsed_page = BeautifulSoup(ret.text,"html.parser")
                    print("Capturando links para a fronteira")
                    total_links = parsed_page.find_all('a')
                    print("Total de links na página:\t"+str(len(total_links)))

                    lenght_front_count_aux = len(link_to_access_list)

                    for linkItem in total_links:
                        putLinkToAccessList(domain, linkItem)
                    
                    if len(link_to_access_list)==5000:
                        print("Limiar da fronteira Atingido!")
                        break
                        
                    lenght_front_count_aux = len(link_to_access_list) - lenght_front_count_aux

                    print("Total de links adicionados a fronteira:\t"+str(lenght_front_count_aux))
                    print("Tamanho atual da fronteira:\t"+str(len(link_to_access_list)))
                    print("Crawler concluiu sua passada por "+str(link)+"   ...")
                else:
                    print("O conteúdo do link não é html. O Crawler continuará do próximo na fronteira!")
            except:
                print("Erro ao acessar o link "+str(link)+"\nO Crawler continuará do próximo na fronteira!")
        
        time_to_sleep_aux = random.randint(1,time_to_sleep)
        print("Aguardando "+str(time_to_sleep_aux)+" segundos para a próxima requisição")
        #time.sleep(time_to_sleep_aux)
        
    dict_link_accessed[domain] = link_accessed_list                
    print("Crawler concluiu atividade na semente "+domain+"   ...\n")
    print("\n---------------------\n----\n---------------------\n\n")

print("Crawler finalizou sua atividade")
# Out:
# Crawleando a semente:	srlupa.com.br
# Iniciando Crawler nesta semente em:	pages/sementes/srlupa/srlupa.html
# Total de links na página:	72
# Total de links adicionados a fronteira:	35
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	72
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	35
# Crawler concluiu sua passada por http://srlupa.com.br/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/accounts/login/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	46
# Total de links adicionados a fronteira:	2
# Tamanho atual da fronteira:	37
# Crawler concluiu sua passada por http://srlupa.com.br/accounts/login/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/ofereca-seus-servicos/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	12
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	38
# Crawler concluiu sua passada por http://srlupa.com.br/ofereca-seus-servicos/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	347
# Tamanho atual da fronteira:	385
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/empresa/politica-de-privacidade/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	50
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	385
# Crawler concluiu sua passada por http://srlupa.com.br/empresa/politica-de-privacidade/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/empresa/termos-e-condicoes-de-uso/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	49
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	385
# Crawler concluiu sua passada por http://srlupa.com.br/empresa/termos-e-condicoes-de-uso/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/central-de-ajuda/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	55
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/central-de-ajuda/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-9   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-9   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-10   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-10   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-12   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-12   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-6   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-6   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-2   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-2   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-3   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-3   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-11   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-11   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-1   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-1   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-5   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-5   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-7   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-7   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-8   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-8   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/categorias/#category-4   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	424
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	386
# Crawler concluiu sua passada por http://srlupa.com.br/categorias/#category-4   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://blog.srlupa.com.br/tela-iphone-descolando   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	51
# Total de links adicionados a fronteira:	24
# Tamanho atual da fronteira:	410
# Crawler concluiu sua passada por https://blog.srlupa.com.br/tela-iphone-descolando   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://blog.srlupa.com.br/sua-tv-desliga-sozinha-veja-o-que-pode-ser   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	50
# Total de links adicionados a fronteira:	5
# Tamanho atual da fronteira:	415
# Crawler concluiu sua passada por https://blog.srlupa.com.br/sua-tv-desliga-sozinha-veja-o-que-pode-ser   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://blog.srlupa.com.br/7-reparos-de-casa-que-voce-sempre-precisa-fazer   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	58
# Total de links adicionados a fronteira:	16
# Tamanho atual da fronteira:	431
# Crawler concluiu sua passada por https://blog.srlupa.com.br/7-reparos-de-casa-que-voce-sempre-precisa-fazer   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/sobre/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	61
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	431
# Crawler concluiu sua passada por http://srlupa.com.br/sobre/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/central-de-ajuda/perguntas-frequentes/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	81
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	432
# Crawler concluiu sua passada por http://srlupa.com.br/central-de-ajuda/perguntas-frequentes/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/cadastro-sr-lupa/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	2
# Tamanho atual da fronteira:	434
# Crawler concluiu sua passada por http://srlupa.com.br/cadastro-sr-lupa/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/eventos/fotografia/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	205
# Total de links adicionados a fronteira:	36
# Tamanho atual da fronteira:	470
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/eventos/fotografia/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/tecnologia/analista-de-ti/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	281
# Total de links adicionados a fronteira:	55
# Tamanho atual da fronteira:	525
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/tecnologia/analista-de-ti/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/construcao-e-reformas/arquiteto/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	329
# Total de links adicionados a fronteira:	66
# Tamanho atual da fronteira:	591
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/construcao-e-reformas/arquiteto/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/construcao-e-reformas/eletricista/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	1569
# Total de links adicionados a fronteira:	322
# Tamanho atual da fronteira:	913
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/construcao-e-reformas/eletricista/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/construcao-e-reformas/pedreiro/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	899
# Total de links adicionados a fronteira:	53
# Tamanho atual da fronteira:	966
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/construcao-e-reformas/pedreiro/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/construcao-e-reformas/pintor/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	1274
# Total de links adicionados a fronteira:	75
# Tamanho atual da fronteira:	1041
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/construcao-e-reformas/pintor/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/servicos-domesticos/diarista/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	326
# Total de links adicionados a fronteira:	61
# Tamanho atual da fronteira:	1102
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/servicos-domesticos/diarista/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/tecnologia/criacao-de-web-site/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	318
# Total de links adicionados a fronteira:	39
# Tamanho atual da fronteira:	1141
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/tecnologia/criacao-de-web-site/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://blog.srlupa.com.br/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	89
# Total de links adicionados a fronteira:	19
# Tamanho atual da fronteira:	1160
# Crawler concluiu sua passada por http://blog.srlupa.com.br/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/central-de-ajuda/contato/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	54
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1161
# Crawler concluiu sua passada por http://srlupa.com.br/central-de-ajuda/contato/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/accounts/facebook/login/?process=login&next=%2Fdashboard%2F?next=/dashboard/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	10
# Total de links adicionados a fronteira:	10
# Tamanho atual da fronteira:	1171
# Crawler concluiu sua passada por http://srlupa.com.br/accounts/facebook/login/?process=login&next=%2Fdashboard%2F?next=/dashboard/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/accounts/password/reset/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1171
# Crawler concluiu sua passada por http://srlupa.com.br/accounts/password/reset/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://blog.srlupa.com.br/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	89
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1171
# Crawler concluiu sua passada por https://blog.srlupa.com.br/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/alarmes-cftv/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	336
# Total de links adicionados a fronteira:	39
# Tamanho atual da fronteira:	1210
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/alarmes-cftv/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/antena/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	125
# Total de links adicionados a fronteira:	4
# Tamanho atual da fronteira:	1214
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/antena/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/aparelho-de-som/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	80
# Total de links adicionados a fronteira:	5
# Tamanho atual da fronteira:	1219
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/aparelho-de-som/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/aquecedor/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	73
# Total de links adicionados a fronteira:	4
# Tamanho atual da fronteira:	1223
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/aquecedor/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/aquecimento-solar/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	59
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1223
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/aquecimento-solar/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/ar-condicionado/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	308
# Total de links adicionados a fronteira:	33
# Tamanho atual da fronteira:	1256
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/ar-condicionado/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/aspirador-de-po/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	61
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1257
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/aspirador-de-po/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/camera/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	66
# Total de links adicionados a fronteira:	2
# Tamanho atual da fronteira:	1259
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/camera/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/celular/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	205
# Total de links adicionados a fronteira:	20
# Tamanho atual da fronteira:	1279
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/celular/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/cerca-eletrica/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	226
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1280
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/cerca-eletrica/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/coifa-e-exaustor/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	66
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1280
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/coifa-e-exaustor/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/computador-desktop/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	493
# Total de links adicionados a fronteira:	39
# Tamanho atual da fronteira:	1319
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/computador-desktop/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/cortina-e-persiana/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	66
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1319
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/cortina-e-persiana/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/dvd-blue-ray/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	65
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1319
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/dvd-blue-ray/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/filtro-de-agua/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	103
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1320
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/filtro-de-agua/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/fogao-cooktop/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	109
# Total de links adicionados a fronteira:	6
# Tamanho atual da fronteira:	1326
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/fogao-cooktop/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/forno-eletrico/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	111
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1327
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/forno-eletrico/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/geladeira-freezer-frigobar/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	180
# Total de links adicionados a fronteira:	4
# Tamanho atual da fronteira:	1331
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/geladeira-freezer-frigobar/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/home-theater/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	76
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1331
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/home-theater/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/impressora/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	196
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1332
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/impressora/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/infraestrutura-de-redes/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	297
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1332
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/infraestrutura-de-redes/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/lava-louca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	113
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1333
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/lava-louca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/lava-roupa/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	191
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1334
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/lava-roupa/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/liquidificador-processador-de-alimento/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	57
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1334
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/liquidificador-processador-de-alimento/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/maquina-costura/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1334
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/maquina-costura/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/micro-ondas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	130
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1334
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/micro-ondas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/notebook-laptop/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	471
# Total de links adicionados a fronteira:	2
# Tamanho atual da fronteira:	1336
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/notebook-laptop/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/seca-roupa/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	96
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1336
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/seca-roupa/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/servidores-linux-windows/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	183
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1337
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/servidores-linux-windows/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/tablet/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	191
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1337
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/tablet/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/telefonia-pabx/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	182
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1337
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/telefonia-pabx/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/televisao/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	112
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1338
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/televisao/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/assistencia-tecnica/video-game/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	94
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1338
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/assistencia-tecnica/video-game/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/artes-artesanato/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	57
# Total de links adicionados a fronteira:	2
# Tamanho atual da fronteira:	1340
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/artes-artesanato/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/artes-desenho/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1340
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/artes-desenho/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/artes-pintura/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1340
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/artes-pintura/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/administracao-concurso/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1341
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/administracao-concurso/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/direito-concurso/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1342
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/direito-concurso/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/informatica-concurso/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	56
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1342
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/informatica-concurso/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/matematica-concurso/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	82
# Total de links adicionados a fronteira:	7
# Tamanho atual da fronteira:	1349
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/matematica-concurso/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/portugues-concurso/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	60
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1350
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/portugues-concurso/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/arabe-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1351
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/arabe-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/brasileira-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	53
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1351
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/brasileira-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/chinesa-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1351
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/chinesa-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/doces-confeitaria-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	53
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1352
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/doces-confeitaria-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/internacional-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1352
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/internacional-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/italiana-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	58
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1352
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/italiana-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/japonesa-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	58
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1352
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/japonesa-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/mexicana-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	58
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1353
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/mexicana-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/tailandesa-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1353
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/tailandesa-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/vegetariana-culinaria/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	53
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1353
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/vegetariana-culinaria/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/axe-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1353
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/axe-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/ballet-jazz-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	47
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1354
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/ballet-jazz-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/forro-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	48
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1355
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/forro-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/funk-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1355
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/funk-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/pole-dance-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	47
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1356
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/pole-dance-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/ritmos-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	52
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1356
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/ritmos-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/salao-samba-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	47
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1357
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/salao-samba-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/ventre-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1357
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/ventre-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/zumba-danca/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1357
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/zumba-danca/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/ciencias-ensino-fundamental/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	78
# Total de links adicionados a fronteira:	4
# Tamanho atual da fronteira:	1361
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/ciencias-ensino-fundamental/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/geografia-ensino-fundamental/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	61
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1361
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/geografia-ensino-fundamental/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/historia-ensino-fundamental/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	72
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1362
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/historia-ensino-fundamental/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/matematica-ensino-fundamental/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	107
# Total de links adicionados a fronteira:	3
# Tamanho atual da fronteira:	1365
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/matematica-ensino-fundamental/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/portugues-ensino-fundamental/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	76
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1366
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/portugues-ensino-fundamental/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/sociologia-filosofia-ensino-fundamental/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	61
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1366
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/sociologia-filosofia-ensino-fundamental/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/biologia-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	66
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1366
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/biologia-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/fisica-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	74
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1366
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/fisica-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/geografia-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	52
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1366
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/geografia-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/historia-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	64
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1366
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/historia-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/matematica-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	94
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1367
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/matematica-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/portugues-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	71
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1367
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/portugues-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/quimica-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	77
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1368
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/quimica-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/sociologia-filosofia-ensino-medio/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	51
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1368
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/sociologia-filosofia-ensino-medio/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/hebraico-aulas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1368
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/hebraico-aulas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/alemao-idiomas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	52
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1369
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/alemao-idiomas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/espanhol-idiomas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	81
# Total de links adicionados a fronteira:	6
# Tamanho atual da fronteira:	1375
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/espanhol-idiomas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/frances-idiomas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	52
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1375
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/frances-idiomas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/ingles-idiomas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	101
# Total de links adicionados a fronteira:	3
# Tamanho atual da fronteira:	1378
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/ingles-idiomas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/italiano-idiomas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	53
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	1379
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/italiano-idiomas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/mandarim-idiomas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	44
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1379
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/mandarim-idiomas/   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar http://srlupa.com.br/profissionais/aulas/portugues-idiomas/   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	51
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	1379
# Crawler concluiu sua passada por http://srlupa.com.br/profissionais/aulas/portugues-idiomas/   ...
# Aguardando 1 segundos para a próxima requisição
# ...
# Total de links na página:	76
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30978
# Crawler concluiu sua passada por https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=2774463&cidade=31000&bairro=0&titulo=99199&logvc=0&bt=3&link=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-2774463/alessia+m+m+ducasse+em+funcionarios?initmap   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-2774463%2Falessia+m+m+ducasse+em+funcionarios&local=controle   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	8
# Total de links adicionados a fronteira:	6
# Tamanho atual da fronteira:	30984
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-2774463%2Falessia+m+m+ducasse+em+funcionarios&local=controle   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-2774463/alessia+m+m+ducasse+em+funcionarios&local=controle&nome=Aléssia M M Ducasse&cidade=MG   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	72
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30984
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-2774463/alessia+m+m+ducasse+em+funcionarios&local=controle&nome=Aléssia M M Ducasse&cidade=MG   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	77
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30984
# Crawler concluiu sua passada por https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/form_login.aspx?ReturnUrl=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios#avaliar   ...
# URL bloqueada pelo robots.txt
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=1907290&cidade=31000&bairro=0&titulo=99199&logvc=0&bt=3&link=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios?initmap   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	77
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30984
# Crawler concluiu sua passada por https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=1907290&cidade=31000&bairro=0&titulo=99199&logvc=0&bt=3&link=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios?initmap   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios#contato_email   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	77
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30984
# Crawler concluiu sua passada por https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios#contato_email   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-1907290%2Falicia+francisca+dos+santos+em+funcionarios&local=controle   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	8
# Total de links adicionados a fronteira:	6
# Tamanho atual da fronteira:	30990
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-1907290%2Falicia+francisca+dos+santos+em+funcionarios&local=controle   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios&local=controle&nome=Alícia Francisca dos Santos&cidade=MG   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	72
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30990
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-1907290/alicia+francisca+dos+santos+em+funcionarios&local=controle&nome=Alícia Francisca dos Santos&cidade=MG   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/locais/br/cidade/psicologos/bu-1937360/aline+costa+do+amaral+fonseca   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	75
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30990
# Crawler concluiu sua passada por https://www.telelistas.net/locais/br/cidade/psicologos/bu-1937360/aline+costa+do+amaral+fonseca   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/form_login.aspx?ReturnUrl=https://www.telelistas.net/locais/br/cidade/psicologos/bu-1937360/aline+costa+do+amaral+fonseca#avaliar   ...
# URL bloqueada pelo robots.txt
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/locais/br/cidade/psicologos/bu-1937360/aline+costa+do+amaral+fonseca#contato_email   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	75
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	30991
# Crawler concluiu sua passada por https://www.telelistas.net/locais/br/cidade/psicologos/bu-1937360/aline+costa+do+amaral+fonseca#contato_email   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fbr%2Fcidade%2Fpsicologos%2Fbu-1937360%2Faline+costa+do+amaral+fonseca&local=controle   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	8
# Total de links adicionados a fronteira:	6
# Tamanho atual da fronteira:	30997
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fbr%2Fcidade%2Fpsicologos%2Fbu-1937360%2Faline+costa+do+amaral+fonseca&local=controle   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/br/cidade/psicologos/bu-1937360/aline+costa+do+amaral+fonseca&local=controle&nome=Aline Costa do Amaral Fonseca&cidade=   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	72
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30997
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/br/cidade/psicologos/bu-1937360/aline+costa+do+amaral+fonseca&local=controle&nome=Aline Costa do Amaral Fonseca&cidade=   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-18411664/ampliare+psicologia+em+centro   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	78
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	30998
# Crawler concluiu sua passada por https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-18411664/ampliare+psicologia+em+centro   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/form_login.aspx?ReturnUrl=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-18411664/ampliare+psicologia+em+centro#avaliar   ...
# URL bloqueada pelo robots.txt
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=18411664&cidade=31000&bairro=0&titulo=99199&logvc=0&bt=3&link=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-18411664/ampliare+psicologia+em+centro?initmap   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	78
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30998
# Crawler concluiu sua passada por https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=18411664&cidade=31000&bairro=0&titulo=99199&logvc=0&bt=3&link=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-18411664/ampliare+psicologia+em+centro?initmap   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=18411664&cidade=31000&bairro=0&titulo=99199&logvc=2&bt=8&acao=site   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	0
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	30998
# Crawler concluiu sua passada por https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=18411664&cidade=31000&bairro=0&titulo=99199&logvc=2&bt=8&acao=site   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-18411664%2Fampliare+psicologia+em+centro&local=controle   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	7
# Total de links adicionados a fronteira:	6
# Tamanho atual da fronteira:	31004
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-18411664%2Fampliare+psicologia+em+centro&local=controle   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-18411664/ampliare+psicologia+em+centro&local=controle&nome=Ampliare Psicologia&cidade=MG   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	72
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	31004
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-18411664/ampliare+psicologia+em+centro&local=controle&nome=Ampliare Psicologia&cidade=MG   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666573/ana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	78
# Total de links adicionados a fronteira:	1
# Tamanho atual da fronteira:	31005
# Crawler concluiu sua passada por https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666573/ana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/form_login.aspx?ReturnUrl=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666573/ana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios#avaliar   ...
# URL bloqueada pelo robots.txt
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=19666573&cidade=31000&bairro=0&titulo=99199&logvc=0&bt=3&link=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666573/ana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios?initmap   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	78
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	31005
# Crawler concluiu sua passada por https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=19666573&cidade=31000&bairro=0&titulo=99199&logvc=0&bt=3&link=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666573/ana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios?initmap   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=19666573&cidade=31000&bairro=0&titulo=99199&logvc=2&bt=8&acao=site   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	0
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	31005
# Crawler concluiu sua passada por https://www.telelistas.net/templates/logredirect.aspx?idcliente=0&tpmat=AG&ct=0&mt=0&uf=mg&id=19666573&cidade=31000&bairro=0&titulo=99199&logvc=2&bt=8&acao=site   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-19666573%2Fana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios&local=controle   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	8
# Total de links adicionados a fronteira:	6
# Tamanho atual da fronteira:	31011
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Facebook&url=https%3A%2F%2Fwww.telelistas.net%2Flocais%2Fmg%2Fbelo+horizonte%2Fpsicologos%2Fbu-19666573%2Fana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios&local=controle   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666573/ana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios&local=controle&nome=Ana Carolina de Almeida Prado - Psicóloga Clínica&cidade=MG   ...
# Página acessada com sucesso
# Capturando links para a fronteira
# Total de links na página:	72
# Total de links adicionados a fronteira:	0
# Tamanho atual da fronteira:	31011
# Crawler concluiu sua passada por https://www.telelistas.net/templates/Redireciona.aspx?origem=Twitter&url=https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666573/ana+carolina+de+almeida+prado+psicologa+clinica+em+funcionarios&local=controle&nome=Ana Carolina de Almeida Prado - Psicóloga Clínica&cidade=MG   ...
# Aguardando 1 segundos para a próxima requisição
# Tentando acessar https://www.telelistas.net/locais/mg/belo+horizonte/psicologos/bu-19666574/ana+carolina+de+almeida+prado+psicologa+clinica+em+savassi   ...

# %%
link_list = []
for key in dict_link_accessed.keys():
    for link in dict_link_accessed[key]:
        link_list.append(link)
len(link_list)

# %%
d = {'link': link_list}
data = pd.DataFrame(data=d)
data
data.to_csv("csv/linksLargura.csv", encoding='utf-8', index = False)
